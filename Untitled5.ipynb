# %%
# Import lớp Image
from PIL import Image
from imagetools import *
from IPython.display import display # to display images

# %%
# Thư mục chứa hình ảnh
dir = 'C://Users/Administrator/Documents/Hieu2024/ThiGiacMayTinh/BaiTapTGMT/img/hoahuongduong.png'

# %%
#Đọc anh
imgs = load_image(dir)

# %%
display(imgs)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x332>

# %%
# Kích thước ban đầu:
print(imgs.size)
# Out:
# (500, 332)

# %%
# Xoay ảnh
rotated_image = imgs.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x332>

# %%
rotated_image = rotated_image.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x332>

# %%
# Transpose ảnh
transposed_image = imgs.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=332x500>

# %%
# Transpose ảnh
transposed_image = transposed_image.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x332>
