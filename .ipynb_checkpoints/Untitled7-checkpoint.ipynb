# %%
# !pip install matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/ACER/Documents/Hieu2024/ThiGiacMayTinh/1.png'
# Đọc ảnh và hiển thị
im = Image.open(my_path)
# display(im)
plt.imshow(im)

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y)
plt.show()

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='red')
plt.show()

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='red') # Màu sắc
plt.title('Ví dụ về biểu đồ') # Title
plt.show() # Hiển thị

# %%
# Tắt hệ trục tọa độ
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]

plt.plot(x, y, color='red')  # Thay đổi màu thành đỏ
plt.title('Biểu đồ ví dụ với màu đỏ')  # Thêm tiêu đề
# Tắt hệ trục tọa độ
plt.axis('off')  # Tắt hệ trục tọa độ
plt.show()

# %%
# Vẽ trên hình ảnh
# ĐỌc ảnh
im = Image.open(my_path)
y = [400,400,400,1000]
x = [750,1000,1250,1000]

plt.imshow(im) # Hiển thị hình ảnh
plt.plot(x,y, 'bo--') 
plt.show()
