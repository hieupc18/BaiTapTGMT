# %%
# Import lớp Image
from PIL import Image
from imagetools import *
from IPython.display import display # to display images

# %%
# Thư mục chứa hình ảnh
dir = 'C://Users/Administrator/Documents/Hieu2024/ThiGiacMayTinh/BaiTapTGMT/img/1.png'

# %%
#Đọc anh
imgs = load_image(dir)

# %%
display(imgs)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1918x1078>

# %%
imgs.size
# Out:
# (1918, 1078)

# %%
#Định vị khu vực cắt
region = (100,100,250,250)
#cắt vùng ảnh
cropped_image = imgs.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=150x150>

# %%
# Dán
# Xác định vị trí cần dán
paste_position = (500,500)
imgs.paste(cropped_image, paste_position)
display(imgs)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1918x1078>

# %%
# Dán
paste_position = (700,500)
imgs.paste(cropped_image, paste_position)
display(imgs)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1918x1078>

# %%
# Dán
paste_position = (700,900)
imgs.paste(cropped_image, paste_position)
display(imgs)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1918x1078>
